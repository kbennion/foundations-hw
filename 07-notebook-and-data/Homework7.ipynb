# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv("07-hw-animals.csv")
print(df)
# Out:
#   animal        name  length
# 0    cat        Anne      35
# 1    cat         Bob      45
# 2    dog  Egglesburg      65
# 3    dog       Devon      50
# 4    cat     Charlie      32
# 5    dog    Fontaine      35

# %%
print(df.columns.values)
# Out:
# ['animal' 'name' 'length']

# %%
print(df['animal'])
# Out:
# 0    cat
# 1    cat
# 2    dog
# 3    dog
# 4    cat
# 5    dog
# Name: animal, dtype: object

# %%
print(df[:3])
# Out:
#   animal        name  length
# 0    cat        Anne      35
# 1    cat         Bob      45
# 2    dog  Egglesburg      65

# %%
print(df)
# Out:
#   animal        name  length
# 0    cat        Anne      35
# 1    cat         Bob      45
# 2    dog  Egglesburg      65
# 3    dog       Devon      50
# 4    cat     Charlie      32
# 5    dog    Fontaine      35

# %%
print(df.sort_values(by='length', ascending=0)[:3])
# Out:
#   animal        name  length
# 2    dog  Egglesburg      65
# 3    dog       Devon      50
# 1    cat         Bob      45

# %%
print(df['animal'])
# Out:
# 0    cat
# 1    cat
# 2    dog
# 3    dog
# 4    cat
# 5    dog
# Name: animal, dtype: object

# %%
print(df['animal'].value_counts())
# Out:
# cat    3
# dog    3
# Name: animal, dtype: int64

# %%
dogs = df[df['animal'] == 'dog']
dogs
# Out:
#   animal        name  length
# 2    dog  Egglesburg      65
# 3    dog       Devon      50
# 5    dog    Fontaine      35

# %%
df[df['length'] > 40]
# Out:
#   animal        name  length
# 1    cat         Bob      45
# 2    dog  Egglesburg      65
# 3    dog       Devon      50

# %%
df['inches'] = df['length'] * .394
df
# Out:
#   animal        name  length  inches
# 0    cat        Anne      35  13.790
# 1    cat         Bob      45  17.730
# 2    dog  Egglesburg      65  25.610
# 3    dog       Devon      50  19.700
# 4    cat     Charlie      32  12.608
# 5    dog    Fontaine      35  13.790

# %%
cats = df[df['animal'] == 'cat']
cats
# Out:
#   animal     name  length  inches
# 0    cat     Anne      35  13.790
# 1    cat      Bob      45  17.730
# 4    cat  Charlie      32  12.608

# %%
dogs = df[df['animal'] == 'dog']
dogs
# Out:
#   animal        name  length  inches
# 2    dog  Egglesburg      65   25.61
# 3    dog       Devon      50   19.70
# 5    dog    Fontaine      35   13.79

# %%
cats[cats['inches'] > 12]
# Out:
#   animal     name  length  inches
# 0    cat     Anne      35  13.790
# 1    cat      Bob      45  17.730
# 4    cat  Charlie      32  12.608

# %%
df[df['inches'] > 12]
df[df['animal'] == 'cat']
#another way: df[(df['animal'] == 'cat') & (df['inches'] > 12)]
# Out:
#   animal     name  length  inches
# 0    cat     Anne      35  13.790
# 1    cat      Bob      45  17.730
# 4    cat  Charlie      32  12.608

# %%
cats['length'].mean()
#see also: cats['length'].describe()
# Out:
# 37.333333333333336

# %%
dogs['length'].mean()
# Out:
# 50.0

# %%
df.groupby('animal')['length'].mean()
# Out:
# animal
# cat    37.333333
# dog    50.000000
# Name: length, dtype: float64

# %%
dogs['length'].hist()

# %%
dogs.plot(kind='scatter', x='length', y='inches')

# %%
df.plot(kind='barh', x='name', y='length', legend=False)

# %%
sortcats = (cats.sort_values(by='length', ascending=0))
sortcats.plot(kind='barh', x='name', y='length', legend=False, sort_columns=False)
#alternately! df[df['animal'] == 'cat'].sort_values(by='length').plot(kind='barh', x='name', y='length')

# %%
cats
# Out:
#   animal     name  length  inches
# 0    cat     Anne      35  13.790
# 1    cat      Bob      45  17.730
# 4    cat  Charlie      32  12.608

# %%
import pandas as pd
df = pd.read_excel("richpeople.xlsx")

# %% [markdown]
# What country are most billionaires from? For the top ones, how many billionaires per billion people?
# Who are the top 10 richest billionaires?
# What's the average wealth of a billionaire? Male? Female?
# Who is the poorest billionaire? Who are the top 10 poorest billionaires?
# 'What is relationship to company'? And what are the most common relationships?
# Most common source of wealth? Male vs. female?
# Given the richest person in a country, what % of the GDP is their wealth?
# Add up the wealth of all of the billionaires in a given country (or a few countries) and then compare it to the GDP of the country, or other billionaires, so like pit the US vs India
# What are the most common industries for billionaires to come from? What's the total amount of billionaire money from each industry?
# How many self made billionaires vs. others?
# How old are billionaires? How old are billionaires self made vs. non self made? or different industries?
# Who are the youngest billionaires? The oldest? Age distribution - maybe make a graph about it?
# Maybe just made a graph about how wealthy they are in general?
# Maybe plot their net worth vs age (scatterplot)
# Make a bar graph of the top 10 or 20 richest

# %% [markdown]
# # How many female billionaires are there compared to male? What industries are they from? What is their average wealth?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print(df['gender'].value_counts())
# Out:
# male              2328
# female             249
# married couple       3
# Name: gender, dtype: int64

# %%
df.groupby('gender')['networthusbillion'].mean()
# Out:
# gender
# female            3.819277
# male              3.516881
# married couple    1.300000
# Name: networthusbillion, dtype: float64

# %%
df.groupby('gender')['sourceofwealth'].value_counts()
# Out:
# gender  sourceofwealth
# female  diversified                          9
#         real estate                          7
#         media                                6
#         construction                         5
#         consumer goods                       5
#         hotels, investments                  5
#         Wal-Mart                             4
#         casinos                              4
#         chemicals                            4
#         cleaning products                    4
#         Samsung                              3
#         banking                              3
#         commodities                          3
#         mining                               3
#         packaging                            3
#         pipelines                            3
#         retail                               3
#         Campbell Soup                        2
#         Cargill Inc.                         2
#         bank, media                          2
#         banking inheritance                  2
#         coffee                               2
#         financial services                   2
#         hotels, restaurants                  2
#         inherited, cosmetics                 2
#         insurance                            2
#         investments                          2
#         medical equipment                    2
#         paper                                2
#         pharmaceuticals                      2
#                                             ..
# male    telecom, oil service, real estate    1
#         telecom, oil, beer                   1
#         telecoms                             1
#         telecoms/lotteries/insurance         1
#         television, Univision                1
#         temp agency                          1
#         textiles, apparel                    1
#         timber/media                         1
#         timberland, lumber mills             1
#         tobacco                              1
#         tobacco distribution, retail         1
#         tobacco, banking                     1
#         tools                                1
#         tourism, construction                1
#         tractors                             1
#         trading company                      1
#         transport                            1
#         travel                               1
#         vaccines                             1
#         vacuums                              1
#         venture capital, Google              1
#         video cameras                        1
#         videogames                           1
#         water                                1
#         water treatment systems              1
#         web hosting                          1
#         wind turbines                        1
#         wine                                 1
#         winter jackets                       1
#         wrestling                            1
# Name: sourceofwealth, dtype: int64

# %% [markdown]
# # Some examples from the review

# %%
df.columns.values
df['countrycode'].value_counts()
# Out:
# USA       903
# DEU       160
# CHN       153
# RUS       119
# JPN        96
# BRA        81
# HKG        77
# FRA        72
# GBR        65
# IND        63
# ITA        58
# CAN        53
# CHE        51
# MEX        44
# Taiwan     40
# ESP        37
# KOR        36
# AUS        33
# TUR        32
# IDN        31
# MYS        28
# SWE        27
# ISR        26
# SGP        26
# THA        23
# SAU        22
# PHL        22
# CHL        19
# ARG        12
# ZAF        12
#          ...
# FIN         5
# ARE         5
# POL         5
# PRT         5
# KAZ         5
# BEL         4
# CYP         4
# DNK         4
# NGA         4
# MAR         4
# MCO         3
# NZL         3
# OMN         2
# MAC         2
# LIE         2
# UGA         1
# ECU         1
# TZA         1
# KNA         1
# VNM         1
# DZA         1
# ROU         1
# SWZ         1
# BHR         1
# BMU         1
# AGO         1
# NPL         1
# LTU         1
# GGY         1
# GEO         1
# Name: countrycode, dtype: int64

# %%
df.sort_values(by='networthusbillion', ascending=False).head(10)
# Out:
#       year              name  rank    citizenship countrycode  \
# 284   2014        Bill Gates     1  United States         USA
# 348   2014  Carlos Slim Helu     2         Mexico         MEX
# 124   2014    Amancio Ortega     3          Spain         ESP
# 283   2001        Bill Gates     1  United States         USA
# 2491  2014    Warren Buffett     4  United States         USA
# 1377  2014     Larry Ellison     5  United States         USA
# 509   2014        David Koch     6  United States         USA
# 381   2014      Charles Koch     6  United States         USA
# 2185  2014   Sheldon Adelson     8  United States         USA
# 429   2014    Christy Walton     9  United States         USA
#
#       networthusbillion   selfmade              typeofwealth  gender   age  \
# 284                76.0  self-made       founder non-finance    male  58.0
# 348                72.0  self-made  privatized and resources    male  74.0
# 124                64.0  self-made       founder non-finance    male  77.0
# 283                58.7  self-made       founder non-finance    male  45.0
# 2491               58.2  self-made       founder non-finance    male  83.0
# 1377               48.0  self-made       founder non-finance    male  69.0
# 509                40.0  inherited                 inherited    male  73.0
# 381                40.0  inherited                 inherited    male  78.0
# 2185               38.0  self-made         self-made finance    male  80.0
# 429                36.7  inherited                 inherited  female  59.0
#
#        ...    relationshiptocompany foundingdate  gdpcurrentus  \
# 284    ...                  founder       1975.0           NaN
# 348    ...                  founder       1990.0           NaN
# 124    ...                  founder       1975.0           NaN
# 283    ...                  founder       1975.0  1.062180e+13
# 2491   ...                  founder       1839.0           NaN
# 1377   ...                  founder       1977.0           NaN
# 509    ...                 relation       1940.0           NaN
# 381    ...                 relation       1940.0           NaN
# 2185   ...                  founder       1952.0           NaN
# 429    ...                 relation       1962.0           NaN
#
#           sourceofwealth                  notes  notes2  \
# 284            Microsoft                    NaN     NaN
# 348              telecom                    NaN     NaN
# 124               retail                    NaN     NaN
# 283                  NaN                    NaN     NaN
# 2491  Berkshire Hathaway                    NaN     NaN
# 1377              Oracle                    NaN     NaN
# 509          diversified  inherited from father     NaN
# 381          diversified  inherited from father     NaN
# 2185             casinos                    NaN     NaN
# 429             Wal-Mart                  widow     NaN
#
#                                                  source  \
# 284           http://www.forbes.com/profile/bill-gates/
# 348   http://www.ozy.com/provocateurs/carlos-slims-w...
# 124       http://www.forbes.com/profile/amancio-ortega/
# 283           http://www.forbes.com/profile/bill-gates/
# 2491  http://www.forbes.com/lists/2009/10/billionair...
# 1377       http://www.forbes.com/profile/larry-ellison/
# 509   http://www.kochind.com/About_Koch/History_Time...
# 381   http://www.kochind.com/About_Koch/History_Time...
# 2185     http://www.forbes.com/profile/sheldon-adelson/
# 429       http://www.forbes.com/profile/christy-walton/
#
#                                                source_2 source_3 source_4
# 284                                                 NaN      NaN      NaN
# 348                                                 NaN      NaN      NaN
# 124                                                 NaN      NaN      NaN
# 283                                                 NaN      NaN      NaN
# 2491  http://www.forbes.com/companies/berkshire-hath...      NaN      NaN
# 1377  http://www.businessinsider.com/how-larry-ellis...      NaN      NaN
# 509                                                 NaN      NaN      NaN
# 381                                                 NaN      NaN      NaN
# 2185  http://lasvegassun.com/news/1996/nov/26/rat-pa...      NaN      NaN
# 429                                                 NaN      NaN      NaN
#
# [10 rows x 30 columns]

# %%
#Who is the poorest billionaire? Top ten poorest?
df.sort_values(by='rank', ascending=False).head(2)
# Out:
#      year              name  rank  citizenship countrycode  networthusbillion  \
# 990  2014          Ina Chan  1565    Hong Kong         HKG                1.0
# 358  2014  Chang Pyung-Soon  1565  South Korea         KOR                1.0
#
#       selfmade         typeofwealth  gender   age   ...     \
# 990  inherited            inherited  female  60.0   ...
# 358  self-made  founder non-finance    male  63.0   ...
#
#     relationshiptocompany foundingdate gdpcurrentus  sourceofwealth     notes  \
# 990              relation       1962.0          NaN         casinos  3rd wife
# 358               founder       1985.0          NaN       education       NaN
#
#      notes2                                           source  \
# 990     NaN          http://www.forbes.com/profile/ina-chan/
# 358     NaN  http://www.forbes.com/profile/chang-pyung-soon/
#
#                                               source_2 source_3 source_4
# 990                                                NaN      NaN      NaN
# 358  http://www.bloomberg.com/research/stocks/priva...      NaN      NaN
#
# [2 rows x 30 columns]

# %%
df[df['networthusbillion'] == 1]
# Out:
#       year                         name  rank     citizenship countrycode  \
# 4     1996       Abdul Aziz Al-Sulaiman   404    Saudi Arabia         SAU
# 19    1996                Adolf Merckle   388         Germany         DEU
# 24    1996              Ahmed Ali Kanoo   383         Bahrain         BHR
# 49    2001                 Albert Frere   490         Belgium         BEL
# 56    2014              Alberto Alcocer  1565           Spain         ESP
# 63    2001                Alberto Vilar   490   United States         USA
# 81    2014                Alexander Vik  1565          Norway         NOR
# 107   1996  Alicia and Esther Koplowitz   405           Spain         ESP
# 108   2001             Alicia Koplowitz   490           Spain         ESP
# 122   2001   Amalia Lacroze de Fortabat   490       Argentina         ARG
# 129   2014                      An Kang  1565           China         CHN
# 131   1996  Ana Maria Brescia Cafferata   401            Peru         PER
# 136   2001              Ananda Krishnan   490        Malaysia         MYS
# 145   2014     Andrea Reimann-Ciardelli  1565   United States         USA
# 164   2014              Andrew Gotianun  1565     Philippines         PHL
# 171   2014               Angela Bennett  1565       Australia         AUS
# 178   2014                Anne Beaufour  1565          France         FRA
# 191   2001              Antonia Johnson   490          Sweden         SWE
# 223   1996                Autrey family   400          Mexico         MEX
# 234   2014                  B.R. Shetty  1565           India         IND
# 247   2001                 Barry Diller   490   United States         USA
# 252   2001           Belmiro de Azevedo   490        Portugal         PRT
# 256   2001       Benjamin de Rothschild   490     Switzerland         CHE
# 261   2014                  Bent Jensen  1565         Denmark         DEN
# 295   1996        Boonsong Asavabhokhin   408        Thailand         THA
# 296   2014                  Boris Mints  1565          Russia         RUS
# 302   2014                Brian Higgins  1565   United States         USA
# 310   2001                 Bruce Kovner   490   United States         USA
# 320   2014                C. James Koch  1565   United States         USA
# 332   1996                  Carl Pohlad   423   United States         USA
# ...    ...                          ...   ...             ...         ...
# 2200  1996             Shoichiro Toyoda   395           Japan         JPN
# 2202  2001                 Shoji Uehara   490           Japan         JPN
# 2203  2014                 Shoji Uehara  1565           Japan         JPN
# 2204  1996              Shoul Eisenberg   392          Israel         ISR
# 2247  2014       Stefan von Holtzbrinck  1565         Germany         DEU
# 2277  1996             Steven Spielberg   422   United States         USA
# 2285  1996               Strwher family   389         Germany         DEU
# 2316  2014            T.S. Kalyanaraman  1565           India         IND
# 2358  2001                Thomas Bailey   490   United States         USA
# 2359  2014                Thomas Bailey  1565   United States         USA
# 2365  2014                Thomas Kaplan  1565   United States         USA
# 2391  2001              Toichi Takenaka   490           Japan         JPN
# 2394  2001                    Tom Gores   490   United States         USA
# 2401  2014                   Tory Burch  1565   United States         USA
# 2439  2001                 Vinod Khosla   490   United States         USA
# 2443  2014          Vivek Chaand Sehgal  1565       Australia         AUS
# 2472  2014                Wang Jianfeng  1565           China         CHN
# 2479  2014                  Wang Muqing  1565           China         CHN
# 2484  2014                    Wang Yong  1565           China         CHN
# 2494  2001                  Wee Cho Yaw   490       Singapore         SGP
# 2504  1996               Werhahn family   390         Germany         DEU
# 2521  2001            William France Jr   490   United States         USA
# 2524  2001           William Hearst III   490   United States         USA
# 2530  2014        William Moncrief, Jr.  1565   United States         USA
# 2537  1996         Winthrop Rockefeller   416   United States         USA
# 2547  2014                  Wu Chung-Yi  1565          Taiwan      Taiwan
# 2549  2014                     Wu Xiong  1565           China         CHN
# 2561  2014                    Yang Keng  1565           China         CHN
# 2591  2014                Zdenek Bakala  1565  Czech Republic         CZE
# 2607  2014                  Zhu Wenchen  1565           China         CHN
#
#       networthusbillion   selfmade              typeofwealth  gender   age  \
# 4                   1.0  self-made         self-made finance    male   0.0
# 19                  1.0  inherited                 inherited    male  61.0
# 24                  1.0  inherited                 inherited    male   0.0
# 49                  1.0  self-made         self-made finance    male  75.0
# 56                  1.0  self-made         self-made finance    male  71.0
# 63                  1.0  self-made         self-made finance    male   NaN
# 81                  1.0  self-made         self-made finance    male  59.0
# 107                 1.0  inherited                 inherited  female   0.0
# 108                 1.0  inherited                 inherited  female  48.0
# 122                 1.0  inherited                 inherited  female   NaN
# 129                 1.0  self-made       founder non-finance    male  65.0
# 131                 1.0  inherited                 inherited  female   0.0
# 136                 1.0  self-made       founder non-finance    male  62.0
# 145                 1.0  inherited                 inherited  female   NaN
# 164                 1.0  self-made         self-made finance    male  86.0
# 171                 1.0  inherited                 inherited  female  69.0
# 178                 1.0  inherited                 inherited  female  50.0
# 191                 1.0  inherited                 inherited  female  57.0
# 223                 1.0        NaN                       NaN     NaN   0.0
# 234                 1.0  self-made       founder non-finance    male  72.0
# 247                 1.0  self-made                 executive    male  59.0
# 252                 1.0  self-made                 executive    male  59.0
# 256                 1.0  inherited                 inherited    male   NaN
# 261                 1.0  inherited                 inherited    male  62.0
# 295                 1.0        NaN                       NaN    male   0.0
# 296                 1.0  self-made         self-made finance    male  55.0
# 302                 1.0  self-made         self-made finance    male  49.0
# 310                 1.0  self-made         self-made finance    male  55.0
# 320                 1.0  self-made       founder non-finance    male  64.0
# 332                 1.0  self-made         self-made finance    male  80.0
# ...                 ...        ...                       ...     ...   ...
# 2200                1.0  inherited                 inherited    male   0.0
# 2202                1.0  inherited                 inherited    male   NaN
# 2203                1.0  inherited                 inherited    male  86.0
# 2204                1.0  self-made  privatized and resources    male   0.0
# 2247                1.0  inherited                 inherited    male  50.0
# 2277                1.0  self-made       founder non-finance    male  49.0
# 2285                1.0        NaN                       NaN     NaN   0.0
# 2316                1.0  self-made       founder non-finance    male  66.0
# 2358                1.0  self-made         self-made finance    male  64.0
# 2359                1.0  self-made         self-made finance    male  77.0
# 2365                1.0  self-made         self-made finance    male  51.0
# 2391                1.0  inherited                 inherited    male  58.0
# 2394                1.0  self-made         self-made finance    male  36.0
# 2401                1.0  self-made       founder non-finance  female  47.0
# 2439                1.0  self-made         self-made finance    male  46.0
# 2443                1.0  self-made       founder non-finance    male  57.0
# 2472                1.0  self-made       founder non-finance    male  44.0
# 2479                1.0  self-made       founder non-finance    male  63.0
# 2484                1.0  self-made       founder non-finance    male  63.0
# 2494                1.0  inherited                 inherited    male  72.0
# 2504                1.0  inherited                 inherited     NaN   0.0
# 2521                1.0  inherited                 inherited    male  68.0
# 2524                1.0  inherited                 inherited    male  51.0
# 2530                1.0  inherited                 inherited    male  93.0
# 2537                1.0  inherited                 inherited    male  47.0
# 2547                1.0  self-made                 executive    male  55.0
# 2549                1.0  self-made                 executive    male   NaN
# 2561                1.0  self-made         self-made finance    male  53.0
# 2591                1.0  self-made  privatized and resources    male  53.0
# 2607                1.0  self-made                 executive    male  48.0
#
#                             ...                          \
# 4                           ...
# 19                          ...
# 24                          ...
# 49                          ...
# 56                          ...
# 63                          ...
# 81                          ...
# 107                         ...
# 108                         ...
# 122                         ...
# 129                         ...
# 131                         ...
# 136                         ...
# 145                         ...
# 164                         ...
# 171                         ...
# 178                         ...
# 191                         ...
# 223                         ...
# 234                         ...
# 247                         ...
# 252                         ...
# 256                         ...
# 261                         ...
# 295                         ...
# 296                         ...
# 302                         ...
# 310                         ...
# 320                         ...
# 332                         ...
# ...                         ...
# 2200                        ...
# 2202                        ...
# 2203                        ...
# 2204                        ...
# 2247                        ...
# 2277                        ...
# 2285                        ...
# 2316                        ...
# 2358                        ...
# 2359                        ...
# 2365                        ...
# 2391                        ...
# 2394                        ...
# 2401                        ...
# 2439                        ...
# 2443                        ...
# 2472                        ...
# 2479                        ...
# 2484                        ...
# 2494                        ...
# 2504                        ...
# 2521                        ...
# 2524                        ...
# 2530                        ...
# 2537                        ...
# 2547                        ...
# 2549                        ...
# 2561                        ...
# 2591                        ...
# 2607                        ...
#
#                      relationshiptocompany foundingdate  gdpcurrentus  \
# 4                                  founder       1968.0  1.577430e+11
# 19                                relation       1881.0  2.500000e+12
# 24                                relation       1890.0  6.100000e+09
# 49                                 founder       1956.0  2.370000e+11
# 56                                   owner       1952.0           NaN
# 63                                 founder       1980.0  1.062180e+13
# 81                                investor       1980.0           NaN
# 107                               relation       1952.0  6.410000e+11
# 108                               relation       1952.0  6.260000e+11
# 122                               relation       1926.0  2.690000e+11
# 129                                founder       1992.0           NaN
# 131                               relation       1889.0  5.397591e+10
# 136                                founder       1984.0  9.278395e+10
# 145                               relation       1923.0           NaN
# 164                                founder       1955.0           NaN
# 171                               relation       1955.0           NaN
# 178                               relation       1929.0           NaN
# 191                               relation       1873.0  2.399170e+11
# 223                                    NaN          NaN  3.974040e+11
# 234                                founder       1975.0           NaN
# 247   Chairman and Chief Executive Officer       1986.0  1.062180e+13
# 252                               chairman       1959.0  1.215460e+11
# 256                               relation       1953.0  2.790000e+11
# 261                               relation       1907.0           NaN
# 295                                    NaN          NaN  1.819480e+11
# 296                                  owner       2010.0           NaN
# 302                                founder       1995.0           NaN
# 310                                founder       1983.0  1.062180e+13
# 320                                founder       1984.0           NaN
# 332                                  owner       1920.0  8.100200e+12
# ...                                    ...          ...           ...
# 2200                              relation       1937.0  4.710000e+12
# 2202                              relation       1912.0  4.160000e+12
# 2203                              relation       1912.0           NaN
# 2204                               founder       1968.0  1.090000e+11
# 2247                              relation       1948.0           NaN
# 2277                               founder       1994.0  8.100200e+12
# 2285                                   NaN          NaN  2.500000e+12
# 2316                               founder       1993.0           NaN
# 2358                               founder       1969.0  1.062180e+13
# 2359                               founder       1969.0           NaN
# 2365                               founder       1993.0           NaN
# 2391                              relation       1610.0  4.160000e+12
# 2394                               founder       1995.0  1.062180e+13
# 2401                               founder       2004.0           NaN
# 2439                               founder       1982.0  1.062180e+13
# 2443                               founder       1986.0           NaN
# 2472                               founder       2004.0           NaN
# 2479                               founder       1999.0           NaN
# 2484                               founder       1986.0           NaN
# 2494                              relation       1935.0  8.928509e+10
# 2504                                   NaN       1844.0  2.500000e+12
# 2521                              relation       1947.0  1.062180e+13
# 2524                              relation       1887.0  1.062180e+13
# 2530                              relation       1929.0           NaN
# 2537                              relation       1870.0  8.100200e+12
# 2547                              investor       1991.0           NaN
# 2549                                 owner       1999.0           NaN
# 2561                              chairman          NaN           NaN
# 2591                               founder       1994.0           NaN
# 2607                              chairman       1999.0           NaN
#
#                sourceofwealth  \
# 4                         NaN
# 19                        NaN
# 24                        NaN
# 49                        NaN
# 56                investments
# 63                        NaN
# 81                investments
# 107                       NaN
# 108                       NaN
# 122                       NaN
# 129           pharmaceuticals
# 131                       NaN
# 136                       NaN
# 145            consumer goods
# 164               real estate
# 171                    mining
# 178           pharmaceuticals
# 191                       NaN
# 223                       NaN
# 234                healthcare
# 247                       NaN
# 252                       NaN
# 256                       NaN
# 261   electric linear systems
# 295                       NaN
# 296               real estate
# 302                Hedge fund
# 310                       NaN
# 320                      beer
# 332                       NaN
# ...                       ...
# 2200                      NaN
# 2202                      NaN
# 2203          pharmaceuticals
# 2204                      NaN
# 2247               publishing
# 2277                      NaN
# 2285                      NaN
# 2316                  jewelry
# 2358                      NaN
# 2359                  finance
# 2365              investments
# 2391                      NaN
# 2394                      NaN
# 2401                  fashion
# 2439                      NaN
# 2443               auto parts
# 2472               auto parts
# 2479        auto distribution
# 2484          food sweeteners
# 2494                      NaN
# 2504                      NaN
# 2521                      NaN
# 2524                      NaN
# 2530                      oil
# 2537                      NaN
# 2547            manufacturing
# 2549           infant formula
# 2561              real estate
# 2591                     coal
# 2607          pharmaceuticals
#
#                                                   notes  \
# 4                                                   NaN
# 19                                       4th generation
# 24                                       3rd generation
# 49                                                  NaN
# 56                          married to Esther Koplowitz
# 63     convicted for money laundering and fraud in 2008
# 81    many business ventures have failed but still m...
# 107                               inherited from father
# 108                               inherited from father
# 122                                               widow
# 129                                                 NaN
# 131                          inherited father's company
# 136                                                 NaN
# 145                               inherited from father
# 164                                                 NaN
# 171                               inherited from father
# 178                                      3rd generation
# 191                                      4th generation
# 223                                                 NaN
# 234                                                 NaN
# 247                                                 NaN
# 252         nationalized in 1974 and reprivitized later
# 256                                      5th generation
# 261                                      3rd generation
# 295                                                 NaN
# 296                                                 NaN
# 302                                                 NaN
# 310                                                 NaN
# 320                                                 NaN
# 332                                                 NaN
# ...                                                 ...
# 2200                                     3rd generation
# 2202                              inherited from father
# 2203                              inherited from father
# 2204                     joint venture with governement
# 2247                              inherited from father
# 2277                                                NaN
# 2285                                                NaN
# 2316                                                NaN
# 2358                                                NaN
# 2359                                                NaN
# 2365                                                NaN
# 2391                            15th or more generation
# 2394                                                NaN
# 2401                                                NaN
# 2439                                                NaN
# 2443  Indian founder of Motherson Sumi, Australian c...
# 2472                                                NaN
# 2479                                                NaN
# 2484                                                NaN
# 2494                              inherited from father
# 2504                                                NaN
# 2521                              inherited from father
# 2524                                     3rd generation
# 2530            joined father's business following WWII
# 2537                                     3rd generation
# 2547                                                NaN
# 2549                                                NaN
# 2561                                                NaN
# 2591                                                NaN
# 2607                                                NaN
#
#                                                  notes2  \
# 4                                                   NaN
# 19                                                  NaN
# 24    With the permission and support of past Bahrai...
# 49                                                  NaN
# 56                                                  NaN
# 63                                                  NaN
# 81                                                  NaN
# 107                fortune split between her and sister
# 108                fortune split between her and sister
# 122                                                 NaN
# 129                                                 NaN
# 131    took part in major business decisions of company
# 136                                                 NaN
# 145                           no involvement in company
# 164                                                 NaN
# 171                         shared fortune with brother
# 178                                                 NaN
# 191            chairman, no siblings, one female cousin
# 223                                                 NaN
# 234                                                 NaN
# 247                                                 NaN
# 252                                                 NaN
# 256   member of Rothschild banking family (founded i...
# 261                                                 NaN
# 295                                                 NaN
# 296                                                 NaN
# 302                                                 NaN
# 310                                                 NaN
# 320                                                 NaN
# 332                                                 NaN
# ...                                                 ...
# 2200                                                NaN
# 2202                                                NaN
# 2203                                                NaN
# 2204                                                NaN
# 2247                                                NaN
# 2277                                                NaN
# 2285                                                NaN
# 2316                                                NaN
# 2358                                                NaN
# 2359                                                NaN
# 2365                                                NaN
# 2391                                                NaN
# 2394                                                NaN
# 2401                                                NaN
# 2439                                                NaN
# 2443                                                NaN
# 2472                                                NaN
# 2479                                                NaN
# 2484                                                NaN
# 2494                                                NaN
# 2504                                                NaN
# 2521                                                NaN
# 2524                                                NaN
# 2530                                                NaN
# 2537                                                NaN
# 2547                                                NaN
# 2549                                                NaN
# 2561                                                NaN
# 2591                                                NaN
# 2607                                                NaN
#
#                                                  source  \
# 4     http://www.arabianbusiness.com/arabian-busines...
# 19                                                  NaN
# 24    http://www.gulf-daily-news.com/NewsDetails.asp...
# 49       http://en.wikipedia.org/wiki/Albert_Fr%C3%A8re
# 56         http://en.wikipedia.org/wiki/Alberto_Alcocer
# 63           http://en.wikipedia.org/wiki/Alberto_Vilar
# 81    http://www.forbes.com/sites/nathanvardi/2014/0...
# 107   http://en.wikipedia.org/wiki/Alicia_Koplowitz,...
# 108   http://en.wikipedia.org/wiki/Alicia_Koplowitz,...
# 122   http://en.wikipedia.org/wiki/Mar%C3%ADa_Amalia...
# 129              http://www.forbes.com/profile/an-kang/
# 131          http://es.wikipedia.org/wiki/Grupo_Brescia
# 136        http://en.wikipedia.org/wiki/Ananda_Krishnan
# 145   http://www.forbes.com/profile/matthias-reimann...
# 164        http://en.wikipedia.org/wiki/Andrew_Gotianun
# 171       http://www.forbes.com/profile/angela-bennett/
# 178                  http://en.wikipedia.org/wiki/Ipsen
# 191   http://en.wikipedia.org/wiki/Antonia_Ax:son_Jo...
# 223   MEXICAN FAMILY ATTEMPTS A COMEBACK WALL STREET...
# 234           http://en.wikipedia.org/wiki/B._R._Shetty
# 247           http://en.wikipedia.org/wiki/Barry_Diller
# 252                  http://en.wikipedia.org/wiki/Sonae
# 256   http://en.wikipedia.org/wiki/Benjamin_de_Roths...
# 261          http://www.forbes.com/profile/bent-jensen/
# 295   http://www.pbs.org/wgbh/pages/frontline/shows/...
# 296          http://www.forbes.com/profile/boris-mints/
# 302      http://www.forbes.com/profile/brian-higgins-1/
# 310           http://en.wikipedia.org/wiki/Bruce_Kovner
# 320    http://en.wikipedia.org/wiki/Samuel_Adams_(beer)
# 332            http://en.wikipedia.org/wiki/Carl_Pohlad
# ...                                                 ...
# 2200      http://en.wikipedia.org/wiki/Shoichiro_Toyoda
# 2202       http://www.forbes.com/profile/shoji-uehara/#
# 2203       http://www.forbes.com/profile/shoji-uehara/#
# 2204    http://en.wikipedia.org/wiki/Israel_Corporation
# 2247    http://www.forbes.com/profile/monika-schoeller/
# 2277      http://en.wikipedia.org/wiki/Steven_Spielberg
# 2285                                                NaN
# 2316     http://en.wikipedia.org/wiki/T.S._Kalyanaraman
# 2358      http://en.wikipedia.org/wiki/Thomas_H._Bailey
# 2359      http://en.wikipedia.org/wiki/Thomas_H._Bailey
# 2365         http://en.wikipedia.org/wiki/Thomas_Kaplan
# 2391  http://en.wikipedia.org/wiki/Takenaka_Corporation
# 2394             http://en.wikipedia.org/wiki/Tom_Gores
# 2401  http://en.wikipedia.org/wiki/J._Christopher_Burch
# 2439          http://en.wikipedia.org/wiki/Vinod_Khosla
# 2443  http://www.forbes.com/profile/vivek-chaand-seh...
# 2472       http://www.forbes.com/profile/wang-jianfeng/
# 2479         http://www.forbes.com/profile/wang-muqing/
# 2484           http://www.forbes.com/profile/wang-yong/
# 2494           http://en.wikipedia.org/wiki/Wee_Cho_Yaw
# 2504      http://de.wikipedia.org/wiki/Wilh._Werhahn_KG
# 2521      http://en.wikipedia.org/wiki/Bill_France,_Jr.
# 2524  http://en.wikipedia.org/wiki/William_Randolph_...
# 2530      http://en.wikipedia.org/wiki/William_Moncrief
# 2537  Agency celebrates 50th with Rockefeller tribut...
# 2547         http://www.forbes.com/profile/wu-chung-yi/
# 2549            http://www.forbes.com/profile/wu-xiong/
# 2561           http://www.forbes.com/profile/yang-keng/
# 2591    http://cs.wikipedia.org/wiki/Zden%C4%9Bk_Bakala
# 2607       http://www.furenpharm.com/aboutus.asp?cid=82
#
#                                                source_2  \
# 4                                                   NaN
# 19                                                  NaN
# 24    http://en.wikipedia.org/wiki/Yusuf_Bin_Ahmed_K...
# 49                http://www.economist.com/node/6823579
# 56       http://www.forbes.com/profile/alberto-alcocer/
# 63    ARTS AND THE MAN The Miami Herald June 17, 200...
# 81                                                  NaN
# 107     http://www.forbes.com/profile/alicia-koplowitz/
# 108     http://www.forbes.com/profile/alicia-koplowitz/
# 122   Australian Financial Review February 28, 2014 ...
# 129   http://english.hualanbio.com/enterhualan/history/
# 131   http://www.forbes.com/profile/ana-maria-bresci...
# 136   http://www.bloomberg.com/research/stocks/priva...
# 145                                                 NaN
# 164      http://www.forbes.com/profile/andrew-gotianun/
# 171                                                 NaN
# 178   http://www.ipsen.com/le-groupe/historique-du-g...
# 191      http://www.forbes.com/profile/antonia-johnson/
# 223                                                 NaN
# 234              http://www.nmchealth.com/dr-br-shetty/
# 247         http://www.forbes.com/profile/barry-diller/
# 252   http://www.fchampalimaud.org/en/the-foundation...
# 256                                                 NaN
# 261                                                 NaN
# 295                                                 NaN
# 296   http://www.o1properties.ru/o1properties/about-...
# 302   http://www.forbes.com/sites/nathanvardi/2014/0...
# 310                             https://www.caxton.com/
# 320   SAM ADAMS CREATOR THRIVES AMID CRAFT BEER SURG...
# 332   http://www.nytimes.com/2009/01/06/sports/baseb...
# ...                                                 ...
# 2200                                                NaN
# 2202  http://en.wikipedia.org/wiki/Taisho_Pharmaceut...
# 2203  http://en.wikipedia.org/wiki/Taisho_Pharmaceut...
# 2204                                                NaN
# 2247                                                NaN
# 2277                                                NaN
# 2285                                                NaN
# 2316  http://www.bloomberg.com/news/articles/2013-01...
# 2358   http://en.wikipedia.org/wiki/Janus_Capital_Group
# 2359   http://en.wikipedia.org/wiki/Janus_Capital_Group
# 2365  http://www.wsj.com/articles/SB1000142405270230...
# 2391                                                NaN
# 2394       http://en.wikipedia.org/wiki/Platinum_Equity
# 2401  http://www.vanityfair.com/news/2007/02/tory-bu...
# 2439  Silicon Valley billionaire likes playing a gam...
# 2443  http://en.wikipedia.org/wiki/Motherson_Sumi_Sy...
# 2472         http://en.joyson.cn/About/RongYuZiZHi.html
# 2479     http://www.zhengtongauto.com/en/milestone.html
# 2484                                                NaN
# 2494  http://en.wikipedia.org/wiki/United_Overseas_Bank
# 2504                 http://www.werhahn.de/en/home.html
# 2521  TOYOTA ENDURES HUMBLING DEBUT;TOP STORIES ALSO...
# 2524    http://en.wikipedia.org/wiki/Hearst_Corporation
# 2530             http://www.moncriefoil.com/history.htm
# 2537                                                NaN
# 2547  http://en.wikipedia.org/wiki/Tingyi_(Cayman_Is...
# 2549                                                NaN
# 2561                                                NaN
# 2591                                                NaN
# 2607         http://www.forbes.com/profile/zhu-wenchen/
#
#                                                source_3  \
# 4                                                   NaN
# 19                                                  NaN
# 24                                                  NaN
# 49                                                  NaN
# 56                                                  NaN
# 63    http://money.cnn.com/2005/05/27/news/newsmaker...
# 81                                                  NaN
# 107                                                 NaN
# 108                                                 NaN
# 122                                                 NaN
# 129                                                 NaN
# 131                                                 NaN
# 136      http://www.forbes.com/profile/ananda-krishnan/
# 145                                                 NaN
# 164   Second-hand car dealer discovers road to riche...
# 171                                                 NaN
# 178        http://www.forbes.com/profile/anne-beaufour/
# 191                                                 NaN
# 223                                                 NaN
# 234                                                 NaN
# 247   VIVENDI TO ENLIST DILLER AS CO-CEO;STRUGGLING ...
# 252                                                 NaN
# 256                                                 NaN
# 261                                                 NaN
# 295                                                 NaN
# 296   http://www.bloomberg.com/research/stocks/priva...
# 302                                                 NaN
# 310   Bruce Kovner, Influential Hedge Fund Manager, ...
# 320                                                 NaN
# 332                                                 NaN
# ...                                                 ...
# 2200                                                NaN
# 2202                                                NaN
# 2203                                                NaN
# 2204                                                NaN
# 2247                                                NaN
# 2277                                                NaN
# 2285                                                NaN
# 2316                                                NaN
# 2358  http://archive.fortune.com/magazines/fortune/f...
# 2359  http://archive.fortune.com/magazines/fortune/f...
# 2365                                                NaN
# 2391                                                NaN
# 2394                                                NaN
# 2401                                                NaN
# 2439                                                NaN
# 2443                                                NaN
# 2472                                                NaN
# 2479                                                NaN
# 2484                                                NaN
# 2494  Wee Cho Yaw highest paid of local bank heads; ...
# 2504                                                NaN
# 2521                                                NaN
# 2524  SF UNZIPPED BLOG The San Francisco Chronicle (...
# 2530                                                NaN
# 2537                                                NaN
# 2547  Tingyi-Campbell sale talks stay on track South...
# 2549                                                NaN
# 2561                                                NaN
# 2591                                                NaN
# 2607                                                NaN
#
#                                                source_4
# 4                                                   NaN
# 19                                                  NaN
# 24                                                  NaN
# 49                                                  NaN
# 56                                                  NaN
# 63                                                  NaN
# 81                                                  NaN
# 107                                                 NaN
# 108                                                 NaN
# 122                                                 NaN
# 129                                                 NaN
# 131                                                 NaN
# 136                                                 NaN
# 145                                                 NaN
# 164                                                 NaN
# 171                                                 NaN
# 178                                                 NaN
# 191                                                 NaN
# 223                                                 NaN
# 234                                                 NaN
# 247                                                 NaN
# 252                                                 NaN
# 256                                                 NaN
# 261                                                 NaN
# 295                                                 NaN
# 296                                                 NaN
# 302                                                 NaN
# 310                                                 NaN
# 320                                                 NaN
# 332                                                 NaN
# ...                                                 ...
# 2200                                                NaN
# 2202                                                NaN
# 2203                                                NaN
# 2204                                                NaN
# 2247                                                NaN
# 2277                                                NaN
# 2285                                                NaN
# 2316                                                NaN
# 2358                                                NaN
# 2359                                                NaN
# 2365                                                NaN
# 2391                                                NaN
# 2394                                                NaN
# 2401                                                NaN
# 2439                                                NaN
# 2443  Will Vivek Sehgal’s Gambit Pay Off? Rashmi K P...
# 2472                                                NaN
# 2479                                                NaN
# 2484                                                NaN
# 2494                                                NaN
# 2504                                                NaN
# 2521                                                NaN
# 2524                                                NaN
# 2530                                                NaN
# 2537                                                NaN
# 2547                                                NaN
# 2549                                                NaN
# 2561                                                NaN
# 2591                                                NaN
# 2607                                                NaN
#
# [171 rows x 30 columns]

# %%
df['networthusbillion'].describe()
# Out:
# count    2614.000000
# mean        3.531943
# std         5.088813
# min         1.000000
# 25%         1.400000
# 50%         2.000000
# 75%         3.500000
# max        76.000000
# Name: networthusbillion, dtype: float64

# %%
df.groupby("gender")["networthusbillion"].describe()
# Out:
# gender
# female          count     249.000000
#                 mean        3.819277
#                 std         5.046177
#                 min         1.000000
#                 25%         1.400000
#                 50%         2.100000
#                 75%         3.700000
#                 max        36.700000
# male            count    2328.000000
#                 mean        3.516881
#                 std         5.123194
#                 min         1.000000
#                 25%         1.400000
#                 50%         2.000000
#                 75%         3.400000
#                 max        76.000000
# married couple  count       3.000000
#                 mean        1.300000
#                 std         0.264575
#                 min         1.000000
#                 25%         1.200000
#                 50%         1.400000
#                 75%         1.450000
#                 max         1.500000
# Name: networthusbillion, dtype: float64

# %%
#Adding the wealt of all the billionaires in a given country.
df.groupby('countrycode')['networthusbillion'].sum().sort_values(ascending=False)
# Out:
# countrycode
# USA       3542.1
# DEU        671.0
# RUS        434.9
# CHN        377.1
# HKG        338.2
# FRA        336.9
# JPN        280.3
# BRA        224.7
# ITA        220.3
# IND        210.8
# MEX        202.6
# GBR        190.6
# CAN        175.3
# CHE        168.6
# SWE        164.8
# ESP        142.4
# Taiwan     112.0
# SAU        106.3
# AUS         93.2
# KOR         86.8
# MYS         86.4
# IDN         80.6
# SGP         68.4
# PHL         67.6
# ISR         65.7
# TUR         65.4
# THA         60.3
# CHL         52.7
# NLD         38.5
# COL         36.3
#            ...
# ARE         16.5
# KWT         15.5
# PRT         13.6
# FIN         13.3
# PER         12.9
# POL         12.8
# NZL         10.8
# KAZ          9.2
# BEL          9.0
# DNK          8.9
# MAR          7.4
# GEO          5.2
# MCO          4.6
# AGO          3.7
# SWZ          3.7
# DZA          3.2
# LIE          2.9
# MAC          2.8
# GGY          2.4
# OMN          2.3
# BMU          2.1
# VNM          1.6
# KNA          1.2
# ECU          1.2
# ROU          1.2
# NPL          1.1
# UGA          1.1
# BHR          1.0
# LTU          1.0
# TZA          1.0
# Name: networthusbillion, dtype: float64

# %%
#What are the most common industries for billionaires to come from?
df['industry'].value_counts()
# Out:
# Consumer                           471
# Retail, Restaurant                 281
# Real Estate                        280
# Money Management                   249
# Media                              219
# Technology-Computer                208
# Diversified financial              167
# Energy                             132
# Technology-Medical                 111
# Non-consumer industrial            107
# Constrution                         97
# Mining and metals                   90
# Other                               83
# Hedge funds                         67
# Private equity/leveraged buyout     25
# 0                                   16
# Venture Capital                      8
# banking                              1
# services                             1
# Name: industry, dtype: int64

# %%
df.groupby('industry')['networthusbillion'].sum()
# Out:
# industry
# 0                                    24.7
# Constrution                         236.4
# Consumer                           1756.3
# Diversified financial               702.9
# Energy                              433.3
# Hedge funds                         223.8
# Media                               852.5
# Mining and metals                   282.8
# Money Management                    710.7
# Non-consumer industrial             348.9
# Other                               222.8
# Private equity/leveraged buyout      87.9
# Real Estate                         844.2
# Retail, Restaurant                 1161.3
# Technology-Computer                1015.2
# Technology-Medical                  311.0
# Venture Capital                      14.2
# banking                               1.3
# services                              1.2
# Name: networthusbillion, dtype: float64

# %%
young_bills = df[df['age'] < 40]
young_bills.plot(kind='barh', x='name', y='networthusbillion').sort_values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-246e6df5715b> in <module>()
#       1 young_bills = df[df['age'] < 40]
# ----> 2 young_bills.plot(kind='barh', x='name', y='networthusbillion').sort_values()
#
# AttributeError: 'AxesSubplot' object has no attribute 'sort_values'

# %%
import pandas as pd
import matplotlib.pplot as plt
plt.style.use("ggplot")
# %matplot
